# %%
# Data Science Tools and Techniques

# %%
## Introduction  
#This notebook summarizes key tools, languages, and libraries used in data science.

# %%
## Data Science Languages  
Here are some commonly used languages in data science:  
1. Python  
2. R  
3. SQL  
4. Java  
5. Scala

# %%
## Data Science Libraries  
Popular libraries include:  
1. Pandas  
2. NumPy  
3. Matplotlib  
4. Scikit-learn  
5. TensorFlow
# Out:
#   Cell In[1], line 2
#     Popular libraries include:
#             ^
# SyntaxError: invalid syntax

# %%
## Data Science Tools  

| Tool           | Description                        |
|----------------|------------------------------------|
| Jupyter Notebook | Interactive coding environment     |
| RStudio        | IDE for R programming              |
| Apache Spark   | Big data processing framework      |
| VS Code        | Lightweight code editor            |
| Tableau        | Data visualization software        |

# %%
## Arithmetic Expressions  
Below are examples of basic arithmetic operations using Python.

# %%
# Multiply and add numbers
result = (5 * 4) + 3
result
# Out:
# 23

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %%
## Objectives  
- Understand key data science languages  
- Explore popular libraries and tools  
- Practice basic arithmetic operations in Python  
- Learn to share notebooks via GitHub
# Out:
#   Cell In[4], line 2
#     - Understand key data science languages
#                  ^
# SyntaxError: invalid syntax

# %%
## Author  
PATHA AKASH
